# %%
from new_main import *
import time
import numpy as np

# %%
# return a list with every endpoint that has over 0% of a certain topic (new_datasets[i], where i == topic)
def filter_sub_topics_over_0(mod, dataset):
    dataset = create_table_ids_topics(mod)
    d_0 = dataset_topics_over_zero(dataset)
    endps = [filter_endpoints_by_topic(d_0, i) for i in range(mod.cur_model_topic_quantity())]
    new_datasets = [new_dataset_filtered_endpoint(data_lemmatized, endp) for endp in endps]
    return endps, new_datasets

# Return a dictionary with the best endpoints for each topic [id of endpoint, topic it belongs, % of topic]
def endpoints_for_topic(mod, tpc):
    dataset = create_table_ids_topics(mod)
    d_best = dataset_topics_over_zero(dataset)
    dict_best = {i: (d_best[i][j][0], d_best[i][j][1]) for i in range(len(d_best)) for j in range(len(d_best[i])) if d_best[i][j][0] == tpc}
    ordered_d = sorted(dict_best.items(), key=lambda x:x[1][1], reverse=True)
    return ordered_d

# Return a dictionary with the best endpoints for each topic [id of endpoint, topic it belongs, % of topic]
def best_endpoints_for_topic(mod, tpc):
    dataset = create_table_ids_topics(mod)
    d_oz = dataset_topics_over_zero(dataset)
    dict_best = {}
    for i in range(len(d_oz)):
        best_score = -1
        best_tpc = None
        for j in range(len(d_oz[i])):
            if(d_oz[i][j][1] > best_score):
                best_score = d_oz[i][j][1]
                best_tpc = d_oz[i][j][0]
        if(best_tpc == tpc):       
            dict_best[i] = (best_tpc, best_score) 
    ordered_d = sorted(dict_best.items(), key=lambda x:x[1][1], reverse=True)
    return ordered_d

def gen_csv_to_topics(mod, bests, id_info):
    csv_vals = []
    for i in range(mod.cur_model_topic_quantity()):
        for j in range(5):
            csv_vals.append(i)
            csv_vals.append(', '.join([elem[0] for elem in mod.cur_model_topic_words(i, 5)]))
            endp_id = bests[i][j][0]
            endp_score = bests[i][j][1][1]
            info = id_info[endp_id]
            csv_vals.append(info[0] + info[1])
            csv_vals.append(endp_score)
            
    return csv_vals

def gen_csv_to_statistics(mod, bests, id_info):
    csv_vals = []
    m = mod._Gensim_Model__current_model
    c = mod._Gensim_Model__corpus
    idw2 = mod._Gensim_Model__id2words
    d_l = mod._Gensim_Model__data_lemmatized
    tpcs = {}
    top_topics = m.top_topics(c, d_l, idw2, coherence='c_v', topn=5)
    top_topics = {', '.join([word[1] for word in top_topics[i][0]]): top_topics[i][1] for i in range(len(top_topics))}
    
    print(top_topics)
    
    for i in range(mod.cur_model_topic_quantity()):
        words_tpc = [elem[0] for elem in mod.cur_model_topic_words(i, 5)]
        weights_w_tpc = [elem[1] for elem in mod.cur_model_topic_words(i, 5)]
        tpc = ', '.join(words_tpc)
        tpcs[i] = top_topics[tpc]
        best_i = [bests[i][j][1][1] for j in range(len(bests[i]))]
        avg_score, std_score = np.average(best_i), np.std(best_i)
        avg_weights, std_weights = np.average(weights_w_tpc), np.std(weights_w_tpc)
        qtt_endpoints = len(bests[i])
        csv_vals.append(i)
        csv_vals.append(tpcs[i]) 
        csv_vals.append(avg_score) 
        csv_vals.append(std_score) 
        csv_vals.append(avg_weights) 
        csv_vals.append(std_weights)
        csv_vals.append(qtt_endpoints)
        
    return csv_vals

# %%
# Loading the dataset into variables, with the endpoints' description lemmatized and a dictionary of endpoint id -> information 
t0 = time.time()
data_lemmatized, id_info = prepare_dataset()
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Time taken: 34.8973867893219 seconds

# %%
# Create the model with the lemmatized data, and try to model the topics 2-20, with LDA, LSA and NMF
t0 = time.time()
mod = evaluate_and_set_best_model(data_lemmatized)
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Latent Dirichlet Allocation (LDA), c_v, 2, 5, 0.48600392227043915
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 2, 5, 0.581088045279271
# Non Negative Matrix Factorization (NMF), c_v, 2, 5, 0.542969009996337
# Latent Dirichlet Allocation (LDA), c_v, 3, 5, 0.5170370624460126
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 3, 5, 0.5205065979855491
# Non Negative Matrix Factorization (NMF), c_v, 3, 5, 0.633244834642606
# Latent Dirichlet Allocation (LDA), c_v, 4, 5, 0.4672813264062485
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 4, 5, 0.553342069010452
# Non Negative Matrix Factorization (NMF), c_v, 4, 5, 0.6044404515680454
# Latent Dirichlet Allocation (LDA), c_v, 5, 5, 0.48101850010476543
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 5, 5, 0.5916308490507415
# Non Negative Matrix Factorization (NMF), c_v, 5, 5, 0.5947677115212902
# Latent Dirichlet Allocation (LDA), c_v, 6, 5, 0.49866673502108094
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 6, 5, 0.5632323935392344
# Non Negative Matrix Factorization (NMF), c_v, 6, 5, 0.6522604864923625
# Latent Dirichlet Allocation (LDA), c_v, 7, 5, 0.5311738490261722
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 7, 5, 0.6338542431352775
# Non Negative Matrix Factorization (NMF), c_v, 7, 5, 0.5838814550632362
# Latent Dirichlet Allocation (LDA), c_v, 8, 5, 0.5078644709268764
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 8, 5, 0.6538864646466208
# Non Negative Matrix Factorization (NMF), c_v, 8, 5, 0.5882834886826696
# Latent Dirichlet Allocation (LDA), c_v, 9, 5, 0.5054565667343409
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 9, 5, 0.5858965836030503
# Non Negative Matrix Factorization (NMF), c_v, 9, 5, 0.6153936716950839
# Latent Dirichlet Allocation (LDA), c_v, 10, 5, 0.5258503134679701
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 10, 5, 0.6019341258314679
# Non Negative Matrix Factorization (NMF), c_v, 10, 5, 0.5818239020592977
# Latent Dirichlet Allocation (LDA), c_v, 11, 5, 0.479927394438338
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 11, 5, 0.48807548407547574
# Non Negative Matrix Factorization (NMF), c_v, 11, 5, 0.5989641459914598
# Latent Dirichlet Allocation (LDA), c_v, 12, 5, 0.458920618534429
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 12, 5, 0.5562148573168998
# Non Negative Matrix Factorization (NMF), c_v, 12, 5, 0.6548922432786117
# Latent Dirichlet Allocation (LDA), c_v, 13, 5, 0.532102079313848
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 13, 5, 0.5232406576040263
# Non Negative Matrix Factorization (NMF), c_v, 13, 5, 0.614327636799451
# Latent Dirichlet Allocation (LDA), c_v, 14, 5, 0.5040845264539137
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 14, 5, 0.5706905586499805
# Non Negative Matrix Factorization (NMF), c_v, 14, 5, 0.6041582041849437
# Latent Dirichlet Allocation (LDA), c_v, 15, 5, 0.5176629374593049
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 15, 5, 0.536146833264274
# Non Negative Matrix Factorization (NMF), c_v, 15, 5, 0.605418323851811
# Latent Dirichlet Allocation (LDA), c_v, 16, 5, 0.5267676957472485
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 16, 5, 0.606638581085212
# Non Negative Matrix Factorization (NMF), c_v, 16, 5, 0.6030860658868484
# Latent Dirichlet Allocation (LDA), c_v, 17, 5, 0.4981299807903922
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 17, 5, 0.5532218893801766
# Non Negative Matrix Factorization (NMF), c_v, 17, 5, 0.6275679024551
# Latent Dirichlet Allocation (LDA), c_v, 18, 5, 0.48706657738159126
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 18, 5, 0.53563853479808
# Non Negative Matrix Factorization (NMF), c_v, 18, 5, 0.6135596598462779
# Latent Dirichlet Allocation (LDA), c_v, 19, 5, 0.4870125906974266
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 19, 5, 0.5127055488499156
# Non Negative Matrix Factorization (NMF), c_v, 19, 5, 0.6275788351411705
# Latent Dirichlet Allocation (LDA), c_v, 20, 5, 0.4879700257073073
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 20, 5, 0.5413690878129522
# Non Negative Matrix Factorization (NMF), c_v, 20, 5, 0.5805031207878587
# Time taken: 1101.5349733829498 seconds

# %%
# For each topic generate a list with the endpoint that is best related to the topic
t0 = time.time()
bests = [best_endpoints_for_topic(mod, i) for i in range(mod.cur_model_topic_quantity())]
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Time taken: 93.8808343410492 seconds

# %%
#len(best)

# %%
for i in range(mod.cur_model_topic_quantity()):
    print('Topic {} has the following words as its highest weight:'.format(i))
    print(mod.cur_model_topic_words(i, 5))
    print('The endpoints that are best related to the topic are the following (endpoint_id, value):')
    for j in range(5):
        print((bests[i][j][0], bests[i][j][1][1]))
    print()
# Out:
# Topic 0 has the following words as its highest weight:
# [('get', 0.0669169989218362), ('list', 0.046666187614072915), ('filter', 0.031010050778435817), ('give', 0.029935052711474647), ('service', 0.02639571359849857)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (0, 1.0)
# (445, 1.0)
# (618, 1.0)
# (628, 1.0)
# (633, 1.0)
#
# Topic 1 has the following words as its highest weight:
# [('api', 0.06921266623079911), ('user', 0.04092281531664043), ('call', 0.018439558511459238), ('see', 0.015073819874472434), ('endpoint', 0.014902130720897374)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (119, 1.0)
# (4308, 1.0)
# (5790, 1.0)
# (5892, 1.0)
# (6579, 1.0)
#
# Topic 2 has the following words as its highest weight:
# [('would', 0.043758343512318734), ('-PRON-', 0.04230971448287902), ('list', 0.041454561157330996), ('endpoint', 0.03688487809161816), ('request', 0.023967186942227506)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (4306, 1.0)
# (622, 0.9848981992768395)
# (8179, 0.9822207627730289)
# (6523, 0.9603485321922467)
# (6712, 0.9600146512295318)
#
# Topic 3 has the following words as its highest weight:
# [('application', 0.03746155754328437), ('service', 0.0321685480474735), ('type', 0.026536403764882293), ('health', 0.023062622060284622), ('specify', 0.022621987212746806)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (2, 1.0)
# (1295, 1.0)
# (1462, 1.0)
# (1883, 1.0)
# (5085, 0.9774484161856152)
#
# Topic 4 has the following words as its highest weight:
# [('field', 0.08305761742195304), ('information', 0.025768537878614738), ('group', 0.022395554064152674), ('provide', 0.02160117549513462), ('include', 0.02150428164951794)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (7779, 1.0)
# (5357, 0.9736481819588185)
# (5347, 0.929880854371529)
# (9534, 0.9156351218208979)
# (402, 0.9075184031615091)
#
# Topic 5 has the following words as its highest weight:
# [('name', 0.036901328246169124), ('parameter', 0.03261314911981311), ('file', 0.030934267186344528), ('return', 0.029566578046054635), ('use', 0.02660777009427535)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (406, 1.0)
# (407, 1.0)
# (408, 1.0)
# (409, 1.0)
# (428, 1.0)
#
# Topic 6 has the following words as its highest weight:
# [('account', 0.08525202996574999), ('true', 0.06273854729323246), ('boolean_admin', 0.04434582250888777), ('envelope', 0.02135719106096968), ('docusign', 0.019893894328248903)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (2523, 1.0)
# (3181, 1.0)
# (3187, 1.0)
# (7547, 1.0)
# (9395, 1.0)
#
# Topic 7 has the following words as its highest weight:
# [('value', 0.08167009150879528), ('name', 0.028344080891893747), ('filter', 0.028166269901334393), ('user', 0.023041857826289414), ('search', 0.020579397791014697)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (4302, 1.0)
# (4304, 1.0)
# (5606, 0.9953896017962354)
# (9064, 0.9584863670030974)
# (5926, 0.9438618733477774)
#
# Topic 8 has the following words as its highest weight:
# [('node', 0.14878027016852152), ('file', 0.030983615494860957), ('add', 0.025252293400781858), ('link', 0.024022040691400546), ('folder', 0.018428122326862004)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (486, 1.0)
# (4305, 1.0)
# (8295, 1.0)
# (504, 0.9995469204897456)
# (6152, 0.9942301209081184)
#
# Topic 9 has the following words as its highest weight:
# [('request', 0.04735432362272613), ('status', 0.03710400220429801), ('delete', 0.03215717815341658), ('return', 0.023106304834800823), ('create', 0.015452945729888342)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (2272, 1.0)
# (2659, 1.0)
# (2696, 1.0)
# (3114, 1.0)
# (3809, 1.0)
#
# Topic 10 has the following words as its highest weight:
# [('key', 0.09141456601608978), ('return', 0.041466958053702686), ('object', 0.03395451594488213), ('contain', 0.02504553537358884), ('link', 0.02126755930588701)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (6183, 1.0)
# (831, 0.9552687774780674)
# (6179, 0.9508586717802585)
# (819, 0.9469497226398704)
# (29, 0.9424226839942088)
#
# Topic 11 has the following words as its highest weight:
# [('use', 0.05521127372170872), ('true', 0.038624768058349135), ('account', 0.03694048640002403), ('create', 0.028110124561850573), ('boolean_admin', 0.026259763321179953)]
# The endpoints that are best related to the topic are the following (endpoint_id, value):
# (7722, 0.9175690216759312)
# (3183, 0.9163668395219029)
# (3301, 0.8478350782706967)
# (2657, 0.8475456042932088)
# (1694, 0.8466285937220915)

# %%
id = 445
info = id_info[id]
print('API: {}, \nEndpoint: {} \nDescription: {}'.format(info[0], info[1], info[3]))
print(data_lemmatized[id])
# Out:
# API: ./APIs/azure.com\azsadmin-Quotas\2018-02-09,
# Endpoint: /subscriptions/{subscriptionId}/providers/Microsoft.Compute.Admin/locations/{location}/quotas/{quotaName}/get
# Description: Get an existing Compute Quota.
# ['get', 'exist', 'compute', 'quota']

# %%
#Create new lemmatized datasets, for each topic (new_datasets[0] == lemmatized version of endpoints in topic 0)
t0 = time.time()
endps, new_datasets = filter_sub_topics_over_0(mod, data_lemmatized)
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Topics for each endpoints modeled in a table
# Time taken: 13.454716444015503 seconds

# %%
# Model sub-topics for topic 0
t0 = time.time()
mod_sub0 = evaluate_and_set_best_model(new_datasets[0])
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Latent Dirichlet Allocation (LDA), c_v, 2, 5, 0.3135504251850122
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 2, 5, 0.5373231286813
# Non Negative Matrix Factorization (NMF), c_v, 2, 5, 0.518405437224078
# Latent Dirichlet Allocation (LDA), c_v, 3, 5, 0.42035548787351384
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 3, 5, 0.6481521188327088
# Non Negative Matrix Factorization (NMF), c_v, 3, 5, 0.5901837908453264
# Latent Dirichlet Allocation (LDA), c_v, 4, 5, 0.40859793722867066
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 4, 5, 0.5252570351771952
# Non Negative Matrix Factorization (NMF), c_v, 4, 5, 0.5931478422122805
# Latent Dirichlet Allocation (LDA), c_v, 5, 5, 0.45808237469718804
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 5, 5, 0.41813270742244263
# Non Negative Matrix Factorization (NMF), c_v, 5, 5, 0.59020360888369
# Latent Dirichlet Allocation (LDA), c_v, 6, 5, 0.41139058986661103
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 6, 5, 0.43607355784194635
# Non Negative Matrix Factorization (NMF), c_v, 6, 5, 0.5666794811534038
# Latent Dirichlet Allocation (LDA), c_v, 7, 5, 0.4221765917538719
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 7, 5, 0.46797023633377605
# Non Negative Matrix Factorization (NMF), c_v, 7, 5, 0.5592229989957255
# Latent Dirichlet Allocation (LDA), c_v, 8, 5, 0.4605527952960887
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 8, 5, 0.5378991384023051
# Non Negative Matrix Factorization (NMF), c_v, 8, 5, 0.6280498027619803
# Latent Dirichlet Allocation (LDA), c_v, 9, 5, 0.4269504553834707
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 9, 5, 0.5527081438468842
# Non Negative Matrix Factorization (NMF), c_v, 9, 5, 0.5506224431485154
# Latent Dirichlet Allocation (LDA), c_v, 10, 5, 0.44541597174818764
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 10, 5, 0.46470398343522845
# Non Negative Matrix Factorization (NMF), c_v, 10, 5, 0.610810785548228
# Latent Dirichlet Allocation (LDA), c_v, 11, 5, 0.4721401982616532
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 11, 5, 0.5453680139163833
# Non Negative Matrix Factorization (NMF), c_v, 11, 5, 0.5561943088225841
# Latent Dirichlet Allocation (LDA), c_v, 12, 5, 0.45040771559321663
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 12, 5, 0.47870506794053075
# Non Negative Matrix Factorization (NMF), c_v, 12, 5, 0.635695924812534
# Latent Dirichlet Allocation (LDA), c_v, 13, 5, 0.47223571428120903
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 13, 5, 0.4622588785765155
# Non Negative Matrix Factorization (NMF), c_v, 13, 5, 0.6100636624836896
# Latent Dirichlet Allocation (LDA), c_v, 14, 5, 0.4393670443832934
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 14, 5, 0.4661384942085272
# Non Negative Matrix Factorization (NMF), c_v, 14, 5, 0.6059701599296831
# Latent Dirichlet Allocation (LDA), c_v, 15, 5, 0.5083661178625878
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 15, 5, 0.4657416736728717
# Non Negative Matrix Factorization (NMF), c_v, 15, 5, 0.581184006375923
# Latent Dirichlet Allocation (LDA), c_v, 16, 5, 0.48293141706128584
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 16, 5, 0.5052273885191989
# Non Negative Matrix Factorization (NMF), c_v, 16, 5, 0.5383023605536726
# Latent Dirichlet Allocation (LDA), c_v, 17, 5, 0.48466862276795103
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 17, 5, 0.5317933228675527
# Non Negative Matrix Factorization (NMF), c_v, 17, 5, 0.5796028808117852
# Latent Dirichlet Allocation (LDA), c_v, 18, 5, 0.44587054684745486
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 18, 5, 0.5382651684761672
# Non Negative Matrix Factorization (NMF), c_v, 18, 5, 0.5920293002648687
# Latent Dirichlet Allocation (LDA), c_v, 19, 5, 0.4548855283286482
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 19, 5, 0.46189853560642974
# Non Negative Matrix Factorization (NMF), c_v, 19, 5, 0.6061981927250152
# Latent Dirichlet Allocation (LDA), c_v, 20, 5, 0.5013693929081992
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 20, 5, 0.48976858431972536
# Non Negative Matrix Factorization (NMF), c_v, 20, 5, 0.5695021688263525
# Time taken: 301.37351965904236 seconds

# %%
t0 = time.time()
bests_sub0 = [best_endpoints_for_topic(mod_sub0, i) for i in range(mod_sub0.cur_model_topic_quantity())]
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Time taken: 10.824284791946411 seconds

# %%
for i in range(mod_sub0.cur_model_topic_quantity()):
    print('Topic {} has the following words as its highest weight:'.format(i))
    print(mod_sub0.cur_model_topic_words(i, 5))
    print('The endpoints that are best related to the topic are the following (endpoint_id, %):')
    for j in range(5):
        print((bests_sub0[i][j][0], bests_sub0[i][j][1][1]))
    print()
# Out:
# Topic 0 has the following words as its highest weight:
# [('user', 0.4052311057718351), ('filter', 0.2690587721107555), ('value', 0.257955595706499), ('return', 0.2523012158970444), ('use', 0.24676139836062372)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (2207, 31.884173975306354)
# (2272, 30.309827725638247)
# (4981, 21.768608491744782)
# (2266, 20.433678167635417)
# (1983, 18.898143348001344)
#
# Topic 1 has the following words as its highest weight:
# [('user', -0.6162135928235281), ('return', 0.32362251111400364), ('filter', 0.16951044851893604), ('key', 0.16098813307168452), ('contain', 0.1556922994013812)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (4079, 8.829900270248672)
# (4081, 8.665594238327103)
# (4049, 8.609206426403192)
# (4046, 8.234915132372631)
# (4041, 7.743532986734398)
#
# Topic 2 has the following words as its highest weight:
# [('route', 0.43868103433510935), ('value', -0.4319522099862365), ('filter', -0.3740361890430523), ('alternate', 0.2671726384382022), ('team', 0.15767193469035162)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (4981, 9.303520088587128)
# (2968, 9.089932180360861)
# (2828, 7.664325059149501)
# (2207, 7.220367545838886)
# (3578, 7.202468973387821)

# %%
id = 2207
info = id_info[id]
print('API: {}, \nEndpoint: {} \nDescription: {}'.format(info[0], info[1], info[3]))
print(data_lemmatized[id])
# Out:
# API: ./APIs/bikewise.org\v2,
# Endpoint: /v2/incidents/get
# Description:
# <p>If you’d like more detailed information about bike incidents, use this endpoint. For mapping, <code>locations</code> is probably a better bet.</p>
#
# <p><strong>Notes on location searching</strong>: <br />
# - <code>proximity</code> accepts an ip address, an address, zipcode, city, or latitude,longitude - i.e. <code>70.210.133.87</code>, <code>210 NW 11th Ave, Portland, OR</code>, <code>60647</code>, <code>Chicago, IL</code>, and <code>45.521728,-122.67326</code> are all acceptable<br />
# - <code>proximity_square</code> sets the length of the sides of the square to find matches inside of. The square is centered on the location specified by <code>proximity</code>. It defaults to 100.</p>
#
# ['like', 'detailed', 'information', 'bike', 'incident', 'use', 'endpoint', 'mapping', 'location', 'probably', 'better', 'bet', 'note', 'location', 'search', 'proximity', 'accept', 'ip', 'address', 'address', 'zipcode', 'city', 'latitude_longitude', 'nw', 'th', 'ave', 'portland', 'chicago', 'il', 'acceptable', 'sets', 'length', 'side', 'square', 'find', 'match', 'inside', 'square', 'center', 'location', 'specify', 'proximity', 'default']

# %%
t0 = time.time()
mod_sub1 = evaluate_and_set_best_model(new_datasets[1])
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Latent Dirichlet Allocation (LDA), c_v, 2, 5, 0.5743401741052129
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 2, 5, 0.4555369722303932
# Non Negative Matrix Factorization (NMF), c_v, 2, 5, 0.49362869959612177
# Latent Dirichlet Allocation (LDA), c_v, 3, 5, 0.6038356887848554
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 3, 5, 0.5493553266062928
# Non Negative Matrix Factorization (NMF), c_v, 3, 5, 0.5864257234341214
# Latent Dirichlet Allocation (LDA), c_v, 4, 5, 0.5210194868895611
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 4, 5, 0.5459162544057682
# Non Negative Matrix Factorization (NMF), c_v, 4, 5, 0.5493953582923019
# Latent Dirichlet Allocation (LDA), c_v, 5, 5, 0.4398328926475209
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 5, 5, 0.5279497639513836
# Non Negative Matrix Factorization (NMF), c_v, 5, 5, 0.6311487829880905
# Latent Dirichlet Allocation (LDA), c_v, 6, 5, 0.46355165813873933
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 6, 5, 0.5397440737373739
# Non Negative Matrix Factorization (NMF), c_v, 6, 5, 0.5784460406734814
# Latent Dirichlet Allocation (LDA), c_v, 7, 5, 0.5128339383935855
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 7, 5, 0.48939172293229205
# Non Negative Matrix Factorization (NMF), c_v, 7, 5, 0.5560693587482471
# Latent Dirichlet Allocation (LDA), c_v, 8, 5, 0.5131684366629861
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 8, 5, 0.4965931936564689
# Non Negative Matrix Factorization (NMF), c_v, 8, 5, 0.5941211886411522
# Latent Dirichlet Allocation (LDA), c_v, 9, 5, 0.5044329874347899
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 9, 5, 0.49155837971079464
# Non Negative Matrix Factorization (NMF), c_v, 9, 5, 0.576314930853695
# Latent Dirichlet Allocation (LDA), c_v, 10, 5, 0.541663702266337
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 10, 5, 0.5140874290737532
# Non Negative Matrix Factorization (NMF), c_v, 10, 5, 0.5692946220494164
# Latent Dirichlet Allocation (LDA), c_v, 11, 5, 0.5933849396953831
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 11, 5, 0.46499425152662205
# Non Negative Matrix Factorization (NMF), c_v, 11, 5, 0.45620427128161595
# Latent Dirichlet Allocation (LDA), c_v, 12, 5, 0.5228812844291545
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 12, 5, 0.5436059890284943
# Non Negative Matrix Factorization (NMF), c_v, 12, 5, 0.5423364312908184
# Latent Dirichlet Allocation (LDA), c_v, 13, 5, 0.5485792160667103
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 13, 5, 0.4760804642759127
# Non Negative Matrix Factorization (NMF), c_v, 13, 5, 0.5887927725710563
# Latent Dirichlet Allocation (LDA), c_v, 14, 5, 0.54289713058135
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 14, 5, 0.5047608958511912
# Non Negative Matrix Factorization (NMF), c_v, 14, 5, 0.5647882687125702
# Latent Dirichlet Allocation (LDA), c_v, 15, 5, 0.472058671820563
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 15, 5, 0.4916286445251323
# Non Negative Matrix Factorization (NMF), c_v, 15, 5, 0.5745003482728037
# Latent Dirichlet Allocation (LDA), c_v, 16, 5, 0.5209207067338576
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 16, 5, 0.47699899132364787
# Non Negative Matrix Factorization (NMF), c_v, 16, 5, 0.559101145329485
# Latent Dirichlet Allocation (LDA), c_v, 17, 5, 0.4988228984037879
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 17, 5, 0.5037175222801082
# Non Negative Matrix Factorization (NMF), c_v, 17, 5, 0.590709617595679
# Latent Dirichlet Allocation (LDA), c_v, 18, 5, 0.4747550610508561
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 18, 5, 0.48785305587272365
# Non Negative Matrix Factorization (NMF), c_v, 18, 5, 0.5568071233698036
# Latent Dirichlet Allocation (LDA), c_v, 19, 5, 0.5042333839594373
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 19, 5, 0.48596745774204164
# Non Negative Matrix Factorization (NMF), c_v, 19, 5, 0.5878092766320703
# Latent Dirichlet Allocation (LDA), c_v, 20, 5, 0.5007294926866674
# Latent Semantic Analysis (LSA), aka Latent Semantic Index (LSI), c_v, 20, 5, 0.48874821611341857
# Non Negative Matrix Factorization (NMF), c_v, 20, 5, 0.5396475119200564
# Time taken: 286.70098304748535 seconds

# %%
t0 = time.time()
bests_sub1 = [best_endpoints_for_topic(mod_sub1, i) for i in range(mod_sub1.cur_model_topic_quantity())]
print('Time taken: {} seconds'.format(time.time() - t0))
# Out:
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Topics for each endpoints modeled in a table
# Time taken: 24.207664728164673 seconds

# %%
for i in range(mod_sub1.cur_model_topic_quantity()):
    print('Topic {} has the following words as its highest weight:'.format(i))
    print(mod_sub1.cur_model_topic_words(i, 5))
    print('The endpoints that are best related to the topic are the following (endpoint_id, %):')
    for j in range(5):
        print((bests_sub1[i][j][0], bests_sub1[i][j][1][1]))
    print()
# Out:
# Topic 0 has the following words as its highest weight:
# [('user', 0.06717222532150371), ('email', 0.045696338533723964), ('allow', 0.017116733242016874), ('send', 0.016886120454048813), ('create', 0.016591596554293042)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (188, 1.0)
# (424, 1.0)
# (425, 1.0)
# (448, 1.0)
# (476, 1.0)
#
# Topic 1 has the following words as its highest weight:
# [('value', 0.02859597997360834), ('specify', 0.02002124466638937), ('create', 0.018111399537097582), ('token', 0.0173376236458634), ('must', 0.014805978449973355)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (479, 1.0)
# (2344, 1.0)
# (2650, 1.0)
# (2656, 1.0)
# (2981, 1.0)
#
# Topic 2 has the following words as its highest weight:
# [('field', 0.02540788540171225), ('object', 0.022886181857317448), ('key', 0.02105923408355683), ('request', 0.019106963074859505), ('return', 0.015082693662815144)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (678, 1.0)
# (1868, 1.0)
# (2374, 1.0)
# (3566, 0.9838688092507757)
# (1310, 0.9780116152253827)
#
# Topic 3 has the following words as its highest weight:
# [('use', 0.0387731060206236), ('api', 0.03797056525024368), ('field', 0.03136932601952443), ('image', 0.018221722975669152), ('request', 0.017557948010392194)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (61, 1.0)
# (191, 1.0)
# (192, 1.0)
# (419, 1.0)
# (960, 1.0)
#
# Topic 4 has the following words as its highest weight:
# [('use', 0.02449714451207836), ('team', 0.02164494810209062), ('endpoint', 0.01717528954450562), ('organization', 0.015727403106435563), ('list', 0.012729099915536949)]
# The endpoints that are best related to the topic are the following (endpoint_id, %):
# (351, 1.0)
# (361, 1.0)
# (428, 1.0)
# (429, 1.0)
# (586, 1.0)

# %%
id = 188
info = id_info[id]
print('API: {}, \nEndpoint: {} \nDescription: {}'.format(info[0], info[1], info[3]))
print(data_lemmatized[id])
# Out:
# API: ./APIs/akeneo.com\1.0.0,
# Endpoint: /api/rest/v1/assets/{asset_code}/variation-files/{channel_code}/{locale_code}/post
# Description: This endpoint allows you to upload a new variation file for a given asset, channel and locale.
# ['endpoint', 'allow', 'upload', 'new', 'variation', 'file', 'give', 'asset', 'channel', 'locale']

# %%
csv_topics = gen_csv_to_topics(mod, bests, id_info)
csv_vals[:10]
csv_statistics =
# Out:
# [0,
#  'get, list, filter, give, service',
#  './APIs/1forge.com\\0.0.1/quotes/get',
#  1.0,
#  0,
#  'get, list, filter, give, service',
#  './APIs/azure.com\\alertsmanagement-AlertsManagement\\2018-11-02-privatepreview/subscriptions/{subscriptionId}/resourceGroups/{resourceGroup}/providers/Microsoft.AlertsManagement/actionRules/{actionRuleName}/get',
#  1.0,
#  0,
#  'get, list, filter, give, service']

# %%
from python_to_html import *

# %%
csv_vals = gen_csv_to_topics(mod, bests, id_info)
create_table_with_csv(csv_vals)
# Out:
# [0, 'get, list, filter, give, service', './APIs/1forge.com\\0.0.1/quotes/get', 1.0, 0, 'get, list, filter, give, service', './APIs/azure.com\\azsadmin-Quotas\\2018-02-09/subscriptions/{subscriptionId}/providers/Microsoft.Compute.Admin/locations/{location}/quotas/{quotaName}/get', 1.0, 0, 'get, list, filter, give, service', './APIs/azure.com\\datashare-DataShare\\2018-11-01-preview/providers/Microsoft.DataShare/locations/{location}/consumerInvitations/{invitationId}/get', 1.0, 0, 'get, list, filter, give, service', './APIs/azure.com\\datashare-DataShare\\2018-11-01-preview/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.DataShare/accounts/{accountName}/shareSubscriptions/{shareSubscriptionName}/ConsumerSourceDataSets/get', 1.0, 0, 'get, list, filter, give, service', './APIs/azure.com\\datashare-DataShare\\2018-11-01-preview/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.DataShare/accounts/{accountName}/shareSubscriptions/{shareSubscriptionName}/dataSetMappings/{dataSetMappingName}/get', 1.0, 1, 'api, user, call, see, endpoint', './APIs/agco-ats.com\\v1/api/v2/AftermarketServices/Certificates/get', 1.0, 1, 'api, user, call, see, endpoint', './APIs/geodesystems.com\\1.0.0/repository/entry/show/get', 1.0, 1, 'api, user, call, see, endpoint', './APIs/isendpro.com\\1.1.1/repertoire/post', 1.0, 1, 'api, user, call, see, endpoint', './APIs/je-apis.com\\2.0.0.0/baskets/post', 1.0, 1, 'api, user, call, see, endpoint', './APIs/neutrinoapi.net\\3.4.5/ip-blocklist/post', 1.0, 2, 'would, -PRON-, list, endpoint, request', './APIs/geneea.com\\1.0/s1/topic/get', 1.0, 2, 'would, -PRON-, list, endpoint, request', './APIs/azure.com\\datashare-DataShare\\2018-11-01-preview/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.DataShare/accounts/{accountName}/delete', 0.9848981992768395, 2, 'would, -PRON-, list, endpoint, request', './APIs/shutterstock.com\\1.0.16/v2/contributors/{contributor_id}/collections/get', 0.9822207627730289, 2, 'would, -PRON-, list, endpoint, request', './APIs/neowsapp.com\\1.0/rest/v1/neo/sentry/{asteroid_id}/get', 0.9603485321922467, 2, 'would, -PRON-, list, endpoint, request', './APIs/openfintech.io\\2017-08-24/organizations/{id}/get', 0.9600146512295318, 3, 'application, service, type, health, specify', './APIs/ably.io\\1.1.0/channels/get', 1.0, 3, 'application, service, type, health, specify', './APIs/azure.com\\servicefabric\\5.6/ApplicationTypes/$/Provision/post', 1.0, 3, 'application, service, type, health, specify', './APIs/azure.com\\servicefabric\\6.2.0.9/Applications/{applicationId}/$/SuspendBackup/post', 1.0, 3, 'application, service, type, health, specify', './APIs/azure.com\\web-WebApps\\2016-08-01/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.Web/sites/{name}/config/appsettings/put', 1.0, 3, 'application, service, type, health, specify', './APIs/gitlab.com\\v3/v3/application/settings/put', 0.9774484161856152, 4, 'field, information, group, provide, include', './APIs/salesloft.com\\v2/v2/custom_fields/{id}.json/delete', 1.0, 4, 'field, information, group, provide, include', './APIs/gov.bc.ca\\geocoder\\2.0.0/sites/{siteID}.{outputFormat}/get', 0.9736481819588185, 4, 'field, information, group, provide, include', './APIs/gov.bc.ca\\geocoder\\2.0.0/intersections/{intersectionID}.{outputFormat}/get', 0.929880854371529, 4, 'field, information, group, provide, include', './APIs/zoomconnect.com\\1/api/rest/v1/sms/send/post', 0.9156351218208979, 4, 'field, information, group, provide, include', './APIs/avaza.com\\v1/api/Timesheet/put', 0.9075184031615091, 5, 'name, parameter, file, return, use', './APIs/aviationdata.systems\\v1/v1/airport/autocomplete/{airport_name}/get', 1.0, 5, 'name, parameter, file, return, use', './APIs/aviationdata.systems\\v1/v1/airport/iata/{airport_iata}/get', 1.0, 5, 'name, parameter, file, return, use', './APIs/aviationdata.systems\\v1/v1/ai ...

# %%
m = mod._Gensim_Model__current_model
c = mod._Gensim_Model__corpus
idw2 = mod._Gensim_Model__id2words
d_l = mod._Gensim_Model__data_lemmatized

# %%
m.num_topics
# Out:
# 12

# %%
dir(m)
# Out:
# ['A',
#  'B',
#  '_W',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapt_by_suffix',
#  '_apply',
#  '_dense_dot_csc',
#  '_h',
#  '_h_max_iter',
#  '_h_stop_condition',
#  '_kappa',
#  '_load_specials',
#  '_save_specials',
#  '_setup',
#  '_smart_save',
#  '_solve_w',
#  '_solveproj',
#  '_transform',
#  '_w_error',
# 0.49424471932309544
# 0.6595997225910635
# 0.22826810550720722
# 0.04018480072486363
# 0.015073095840906556
# 2116
# 0.6155617605555058
# 0.5017236631584698
# 0.15353254664977484
# 0.031710198130853726
# 0.02110306857522929
# 1461
# 0.5218229340013093
# 0.5288151796452925
# 0.17160661404726768
# 0.03767493683727489
# 0.007229123883371755
# 1264
# 0.6240891118997645
# 0.47418140034882594
# 0.15097102258274925
# 0.028370223725734316
# 0.005686042073927894
# 981
# 0.6510879143988152
# 0.4852711379097963
# 0.16551795533219615
# 0.03486543330187461
# 0.024146216736580378
# 348
# 0.5828733803625671
# 0.47080864529001754
# 0.15884658505015029
# 0.03132461853853134
# 0.003413260670373178
# 943
# 0.9106093859435193
# 0.523437588165027
# 0.1915046940570605
# 0.04671749703141776
# 0.02493936607410757
# 278
# 0.7322689471938924
# 0.49485343850541047
# 0.17054607389458445
# 0.03636033958386551
# 0.022850806905112556
# 224
# 0.7532945520699723
# 0.488724602452615
# 0.2019902848552609
# 0.049493268416485374
# 0.04980354923354873
# 112
# 0.5488193134332955
# 0.5491644643485165
# 0.20667091599801868
# 0.031034950909025964
# 0.011046058277542759
# 1427
# 0.7461294483530392
# 0.50547289935962
# 0.1788797072973236
# 0.04262982693883009
# 0.025385499167812017
# 245
# 0.6779054518085654
# 0.44403306461579756
# 0.12028862679574628
# 0.03702928321262247
# 0.010282725177395226
# 521
# '\nprint(tpcs[i]) \nprint(avg_score) \nprint(std_score) \nprint(avg_weights) \nprint(std_weights)\nprint(qtt_endpoints)\n'

# %%
dataset = create_table_ids_topics(mod)
d_oz = dataset_topics_over_zero(dataset)
print(d_oz)
# Out:
# Topics for each endpoints modeled in a table
# {0: [[0, 1.0]], 1: [[0, 0.49109968307189106], [2, 0.508900316928109]], 2: [[3, 1.0]], 3: [[0, 0.9572044679298476], [4, 0.030261552809901143], [6, 0.012533979260251217]], 4: [[0, 1.0]], 5: [[1, 0.026372209589300817], [3, 0.5126803009446055], [6, 0.08932201885692477], [7, 0.27283099688699797], [9, 0.08931391926945319]], 6: [[0, 0.9882750568229517], [6, 0.011724943177048234]], 7: [[1, 0.14251977287415632], [3, 0.1612047137693608], [5, 0.2922966976168651], [10, 0.06456669904286404], [11, 0.3394121166967536]], 8: [[4, 0.09430776948295898], [9, 0.6938413962595578], [10, 0.20475120870548674]], 9: [[0, 0.7327147386034016], [2, 0.2633403267413753]], 10: [[2, 0.8185852038054067], [6, 0.08971869212382703], [7, 0.07982719532269214], [11, 0.011868908748074029]], 11: [[5, 0.7139233446580915], [7, 0.09141704697226319], [9, 0.16009178796735427], [10, 0.028294906048501597]], 12: [[2, 0.11852681280132772], [6, 0.0226984243052903], [7, 0.045967675880885205], [8, 0.028704502978420057], [9, 0.7714822018864026], [11, 0.012620382147674218]], 13: [[0, 0.4499408112146216], [2